# %% [markdown]
# # **Planetary boundaries radar chart**
#
# <div style="text-align: left; font-size: 15px;">Author: Michaël Lejeune<sup>a,b</sup><br><br>
#
# <div style="text-align: left; font-size: 15px;"><sup>a</sup>Sustainability in Manufacturing and Life Cycle Engineering Research Group, school of Mechanical and Manufacturing Engineering, the University of New South Wales, 2052, Sydney, Australia<br>
# <div style="text-align: left; font-size: 15px;"><sup>b</sup>Australian Research Council Training Centre for the Global Hydrogen Economy (GlobH2e), the University of New South Wales, 2052, Sydney, Australia <br>

# %%
import numpy as np
import matplotlib.font_manager as fm
import matplotlib.pyplot as plt
# %config InlineBackend.figure_format = 'svg' 
from source.PB import PBchart

# %% [markdown]
# Testing the log scales

# %%
ASR_inter=[0, 0.01, .1, 1, 10, 100, 1000, 10000, 100000]


categories=["Energy  Imbalance",
            "CO2  Concentration",
            "Ocean  Acidification",
            "Atmospheric  Aerosol  Loading",
            "Freshwater  Use",
            "Biogeochemical  Flows  P",
            "Biogeochemical  Flows  N",
            "Stratospheric  Ozone  Depletion",
            "Land-System  Change"
            ]

fig=PBchart(categories=categories,
        values=np.array([ASR_inter]),upper=np.array([ASR_inter]),lower=np.array([ASR_inter]), 
        legend=["2025"],
        figsize=(4,4),
        offsetcat=0.2,scale=7,minscale=-2,median_lw=0.8
)
fig

# %% [markdown]
# more bars, same categories

# %%
ASR1=[-41.76104772057002, 41.76104772057002, 1.4900568364508022, 11.00312614274712, 9.860515756599522, 86.47764602207023, 8.400884978749326, -1.5308754437716912, 3.8921507403870943]

ASR2=[47.00699621049232, 47.00699621049232, 2.7127054403810873, 7.462494835438402, 17.029368135227475, 62.59031311546501, 9.269113317546733, -2.1342777409878453, 4.475817677804179]
categories=["Energy  Imbalance",
            "CO2  Concentration",
            "Ocean  Acidification",
            "Atmospheric  Aerosol  Loading",
            "Freshwater  Use",
            "Biogeochemical  Flows  P",
            "Biogeochemical  Flows  N",
            "Stratospheric  Ozone  Depletion",
            "Land-System  Change"
            ]
fig=PBchart(categories=categories,
        values=np.array([ASR1,ASR2]),upper=np.array([ASR1,ASR2])*3,lower=np.array([ASR1,ASR2])*0.5, 
        legend=["2025","2030"],
        figsize=(4,4),
        offsetcat=.2,scale=4,minscale=-2,median_lw=0.8
)
fig

# %% [markdown]
# more impact categories

# %%
ASR1=[-41.76104772057002, 41.76104772057002, 1.4900568364508022, 11.00312614274712, 9.860515756599522, 86.47764602207023, 8.400884978749326, -1.5308754437716912, 3.8921507403870943, 41.970114750497686]

ASR2 = [47.00699621049232, 47.00699621049232, 2.7127054403810873, 7.462494835438402, 17.029368135227475, 62.59031311546501, 9.269113317546733, -2.1342777409878453, 4.475817677804179, 34.192114847501344]


categories=["Energy  Imbalance",
            "CO2  Concentration",
            "Ocean  Acidification",
            "Atmospheric  Aerosol  Loading",
            "Freshwater  Use",
            "Biogeochemical  Flows  P",
            "Biogeochemical  Flows  N",
            "Stratospheric  Ozone  Depletion",
            "Land-System  Change",
            "Biosphere  Integrity"
            ]

# %%
fig=PBchart(categories=categories,
        values=np.array([ASR1,ASR2]),upper=np.array([ASR1,ASR2])*3,lower=np.array([ASR1,ASR2])*0.5,
        legend=["2025","2030"],
        figsize=(4,4),
        offsetcat=0,scale=4,minscale=-2,median_lw=0.8
)
fig

# %% [markdown]
# more impact categories and bars

# %%
ASR1=[-41.76104772057002, 41.76104772057002, 1.4900568364508022, 11.00312614274712, 9.860515756599522, 86.47764602207023, 8.400884978749326, -1.5308754437716912, 3.8921507403870943, 41.970114750497686]
 
ASR2= [47.00699621049232, 47.00699621049232, 2.7127054403810873, 7.462494835438402, 17.029368135227475, 62.59031311546501, 9.269113317546733, -2.1342777409878453, 4.475817677804179, 34.192114847501344]

ASR3= [69.1977708791746, 69.1977708791746, 5.208771287921971, 4.855131741919654, 29.268025924973664, 50.87794592288904, 13.336418248671588, -3.6222714523307267, 6.687646150400986, 34.752853464581094]

ASR4=  [83.03586167230578, 83.03586167230578, 6.599548670224945, 3.9931101662857076, 35.058307612705384, 49.20976296394141, 15.905642102944043, -4.482311191252119, 8.05023793980117, 37.21440538129681]

ASR5=  [77.94302206850834, 77.94302206850834, 6.104828813278897, 4.0595286858183846, 34.232261875745216, 48.88959261642441, 15.00270933915205, -4.172933509328583, 7.546861560824137, 35.928995472170136]

ASR6=  [63.799019190193604, 63.799019190193604, 4.877800110636659, 3.7734725932934503, 30.637990378423, 43.60559091148284, 12.373303451947496, -3.370785332530633, 6.16597745682443, 30.74215568859776]


categories=["Energy  Imbalance",
            "CO2  Concentration",
            "Ocean  Acidification",
            "Atmospheric  Aerosol  Loading",
            "Freshwater  Use",
            "Biogeochemical  Flows  P",
            "Biogeochemical  Flows  N",
            "Stratospheric  Ozone  Depletion",
            "Land-System  Change",
            "Biosphere  Integrity"
            ]

# %%
fig=PBchart(categories=categories,
        values=np.array([ASR1,ASR2,ASR3,ASR4,ASR5,ASR6]),upper=np.array([ASR1,ASR2,ASR3,ASR4,ASR5,ASR6])*3,lower=np.array([ASR1,ASR2,ASR3,ASR4,ASR5,ASR6])*0.5,
        legend=["2025","2030","2035","2040","2045","2050"],
        figsize=(4,4),
        offsetcat=0,scale=4,minscale=-2,median_lw=0.8
)
fig

# %% [markdown]
# save the figure

# %%
fig.savefig("PB_inter.svg",bbox_inches='tight',dpi=300,transparent=True)
